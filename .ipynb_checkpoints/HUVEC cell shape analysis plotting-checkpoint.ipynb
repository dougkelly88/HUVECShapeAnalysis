# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel, ttest_ind

def do_ttest(ax, category, vs):
    """add t-test to plot"""
    controls = np.array([v for v, cat in zip(vs, category) if ("control" in cat.lower() or "wt" in cat.lower())]);
    experiments = np.array([v for v, cat in zip(vs, category) if not ("control" in cat.lower() or "wt" in cat.lower())])
    p = ttest_ind(controls, experiments).pvalue;
    start_ylims = ax.get_ylim();
    start_plot_height = ax.get_ylim()[1] - ax.get_ylim()[0];
    height_per_comparison = 0.1 * (start_ylims[1] - start_ylims[0]);
    ax.set_ylim(start_ylims[0], start_ylims[1] +  height_per_comparison);
    lx = ax.get_xticks()[0];
    rx = ax.get_xticks()[1];
    mid = lx/2 + rx/2;
    lry = start_ylims[1] + 0.5 * height_per_comparison;
    h = height_per_comparison/4;

    barx = [lx, lx, rx, rx];
    bary = [(lry-h), lry, lry, (lry-h)];
    ax.plot(barx, bary, c='black');
    ax.text(mid, lry + h/2, p_to_stars(p), horizontalalignment='center', fontsize=12);
    return p;

def format_p_value(p, decimal_places=3):
    """ensure p is printed with reasonable precision"""
    if p < 0.01:
        fmt_str = "{" + ":.{}E".format(decimal_places) + "}";
    else:
        fmt_str = "{" + ":.{}F".format(decimal_places) + "}";
    p_str = fmt_str.format(p);
    return p_str;

def p_to_stars(p):
    """map p-values to stars to display on graphs"""
    if p > 0.05:
        return 'n.s.';
    elif p > 0.01:
        return '*';
    elif p > 0.005:
        return '**';
    else:
        return '***';

# %% [markdown]
# First, load data and add column to identify control vs experimental conditions

# %%
csv_path = "D:\\data\\HUVECs\\out\\2019-03-22 10-01-20 output\\output.csv";
df = pd.read_csv(csv_path, encoding='cp1252');
df['Condition'] = ["Experiment" if "marcks" in t.lower() else "Control" for t in df['Image'].tolist()]

# %% [markdown]
# For very crude quality control, include only cells that contain exactly one nucleus

# %%
prev_count = len(df);
df = df[df["# nuclei fully enclosed per cell"]==1];
print("Excluded {} cells based on number of enclosed nuclei".format(prev_count - len(df)));
# Out:
# Excluded 45 cells based on number of enclosed nuclei

# %% [markdown]
# Display plots comparing cell shape parameters for this data.

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(10,5))
sns.boxplot(x='Condition', y='Cell area, µm²', data=df, whis=np.Inf, ax=axs[0]);
p = do_ttest(axs[0], df['Condition'].tolist(), df['Cell area, µm²'].tolist());
sns.swarmplot(x='Condition', y='Cell area, µm²', data=df, ax=axs[0], alpha=0.5);
print("Cell area, µm² control v experiment, p = {}".format(format_p_value(p)));
sns.boxplot(x='Condition', y='Cell spikiness index', data=df, whis=np.Inf, ax=axs[1]);
p = do_ttest(axs[1], df['Condition'].tolist(), df['Cell spikiness index'].tolist());
sns.swarmplot(x='Condition', y='Cell spikiness index', data=df, ax=axs[1], alpha=0.5);
print("Cell spikiness index control v experiment, p = {}".format(format_p_value(p)));
sns.boxplot(x='Condition', y='Cell aspect ratio', data=df, whis=np.Inf, ax=axs[2]);
p = do_ttest(axs[2], df['Condition'].tolist(), df['Cell aspect ratio'].tolist());
sns.swarmplot(x='Condition', y='Cell aspect ratio', data=df, ax=axs[2], alpha=0.5);
print("Cell aspect ratio control v experiment, p = {}".format(format_p_value(p)));
plt.tight_layout();
# Out:
# Cell area, µm² control v experiment, p = 1.159E-19
# Cell spikiness index control v experiment, p = 0.014
# Cell aspect ratio control v experiment, p = 0.399
